# %% [markdown]
# # Working with text data

# %%
## Tokenizing text

import os 
import urllib.request 

file_path = "data.txt"

# %%
with open(file_path,"r",encoding="utf-8") as f :
    raw_text = f.read()
raw_text
# Out:
# 'The Spiritual Phenomenon of Auras: A Comprehensive Analysis of Energy Fields in Human Consciousness\nThe concept of auras represents one of humanity\'s most enduring spiritual beliefs, encompassing the idea that all living beings emanate subtle energy fields that can be perceived, interpreted, and influenced through various practices. This luminous radiation, described across cultures as a colored emanation surrounding the human body, serves as a bridge between the physical and metaphysical realms, offering insights into an individual\'s emotional, mental, and spiritual states. The study of auras reveals a rich tapestry of cross-cultural spiritual wisdom, from ancient Hindu scriptures to modern New Age practices, demonstrating humanity\'s persistent fascination with the invisible forces that shape our existence and consciousness.\n\nHistorical and Cultural Foundations\nAncient Origins and Cross-Cultural Manifestations\nThe belief in auras extends far back into human history, with documented evidence appearing in various ancient civilizations and spiritual traditions. In ancient India, the concept finds its earliest recorded mentions in the Hindu scriptures known as the Upanishads, written between 800 and 400 BCE, which describe the concept of prana, or life force energy. These sacred texts teach that prana flows through all living beings and can be perceived through meditation and spiritual practices, manifesting as an aura that reflects an individual\'s spiritual development and vital essence. The Upanishads establish the foundational understanding that this energy field serves as a visible representation of one\'s inner spiritual state, providing a means for advanced practitioners to assess and guide others on their spiritual journey.\n\nAncient Chinese tradition contributed significantly to the understanding of energy fields through the concept of qi (or chi), meaning vital energy, which became central to traditional medicine and martial arts. Chinese medicine practitioners and martial artists learned to perceive and manipulate this life force that flows through meridians in the body, using it for healing and enhanced physical capabilities. This systematic approach to energy work established many of the principles that would later influence modern aura healing practices. Similarly, ancient Egyptian civilization held beliefs about the "ka," representing a person\'s spiritual essence that continued to exist after death, while ancient Greeks recognized the "aureole," a radiant light surrounding divine figures like gods and heroes.\n\nTheosophical Influence and Modern Development\nThe modern Western understanding of auras was significantly shaped by the work of Charles Webster Leadbeater, a former Church of England priest and member of the Theosophical Society in the early 20th century. Leadbeater claimed to possess clairvoyant abilities that allowed him to make scientific investigations of the human energy field, and his 1903 book "Man Visible and Invisible" illustrated the aura at various stages of human moral evolution. His revolutionary contribution came in 1910 with "The Inner Life," where he incorporated the Tantric notion of chakras, describing them as energy vortices and associating each with specific glands and organs. This synthesis of Eastern and Western esoteric traditions created the foundation for contemporary aura theory.\n\nLeadbeater\'s innovations were subsequently adopted and reinterpreted by other influential theosophists such as Rudolf Steiner and Edgar Cayce, though the concept remained relatively obscure until the 1980s when it was embraced by the New Age movement. This resurrection of interest led to a proliferation of aura-related practices, from aura photography to energy healing modalities, establishing auras as a central component of alternative spirituality. The theosophical interpretation emphasized the multi-layered nature of the aura, with different levels corresponding to various aspects of hum ...

# %%
len(raw_text)
# Out:
# 19616

# %%
import re 

text  =  "Hello , world . This is a test for tokenization using regular expresison"
result = re.split(r'(\s)',text)
print(result)
# Out:
# ['Hello', ' ', ',', ' ', 'world', ' ', '.', ' ', 'This', ' ', 'is', ' ', 'a', ' ', 'test', ' ', 'for', ' ', 'tokenization', ' ', 'using', ' ', 'regular', ' ', 'expresison']

# %%
result = re.split(r'([,.]|\s)',text)
print(result)
# Out:
# ['Hello', ' ', '', ',', '', ' ', 'world', ' ', '', '.', '', ' ', 'This', ' ', 'is', ' ', 'a', ' ', 'test', ' ', 'for', ' ', 'tokenization', ' ', 'using', ' ', 'regular', ' ', 'expresison']

# %%
result = [item  for item in result if item.strip()]
print(result)
# Out:
# ['Hello', ',', 'world', '.', 'This', 'is', 'a', 'test', 'for', 'tokenization', 'using', 'regular', 'expresison']

# %%
result = re.split(r'([,.:;?_!"()\']|--|)\s',raw_text)
result = [item.strip() for item in result if item.strip()]
print(result)
# Out:
# ['The', 'Spiritual', 'Phenomenon', 'of', 'Auras', ':', 'A', 'Comprehensive', 'Analysis', 'of', 'Energy', 'Fields', 'in', 'Human', 'Consciousness', 'The', 'concept', 'of', 'auras', 'represents', 'one', 'of', "humanity's", 'most', 'enduring', 'spiritual', 'beliefs', ',', 'encompassing', 'the', 'idea', 'that', 'all', 'living', 'beings', 'emanate', 'subtle', 'energy', 'fields', 'that', 'can', 'be', 'perceived', ',', 'interpreted', ',', 'and', 'influenced', 'through', 'various', 'practices', '.', 'This', 'luminous', 'radiation', ',', 'described', 'across', 'cultures', 'as', 'a', 'colored', 'emanation', 'surrounding', 'the', 'human', 'body', ',', 'serves', 'as', 'a', 'bridge', 'between', 'the', 'physical', 'and', 'metaphysical', 'realms', ',', 'offering', 'insights', 'into', 'an', "individual's", 'emotional', ',', 'mental', ',', 'and', 'spiritual', 'states', '.', 'The', 'study', 'of', 'auras', 'reveals', 'a', 'rich', 'tapestry', 'of', 'cross-cultural', 'spiritual', 'wisdom', ',', 'from', 'ancient', 'Hindu', 'scriptures', 'to', 'modern', 'New', 'Age', 'practices', ',', 'demonstrating', "humanity's", 'persistent', 'fascination', 'with', 'the', 'invisible', 'forces', 'that', 'shape', 'our', 'existence', 'and', 'consciousness', '.', 'Historical', 'and', 'Cultural', 'Foundations', 'Ancient', 'Origins', 'and', 'Cross-Cultural', 'Manifestations', 'The', 'belief', 'in', 'auras', 'extends', 'far', 'back', 'into', 'human', 'history', ',', 'with', 'documented', 'evidence', 'appearing', 'in', 'various', 'ancient', 'civilizations', 'and', 'spiritual', 'traditions', '.', 'In', 'ancient', 'India', ',', 'the', 'concept', 'finds', 'its', 'earliest', 'recorded', 'mentions', 'in', 'the', 'Hindu', 'scriptures', 'known', 'as', 'the', 'Upanishads', ',', 'written', 'between', '800', 'and', '400', 'BCE', ',', 'which', 'describe', 'the', 'concept', 'of', 'prana', ',', 'or', 'life', 'force', 'energy', '.', 'These', 'sacred', 'texts', 'teach', 'that', 'prana', 'flows', 'through', 'all', 'living', 'beings', 'and', 'can', 'be', 'perceived', 'through', 'meditation', 'and', 'spiritual', 'practices', ',', 'manifesting', 'as', 'an', 'aura', 'that', 'reflects', 'an', "individual's", 'spiritual', 'development', 'and', 'vital', 'essence', '.', 'The', 'Upanishads', 'establish', 'the', 'foundational', 'understanding', 'that', 'this', 'energy', 'field', 'serves', 'as', 'a', 'visible', 'representation', 'of', "one's", 'inner', 'spiritual', 'state', ',', 'providing', 'a', 'means', 'for', 'advanced', 'practitioners', 'to', 'assess', 'and', 'guide', 'others', 'on', 'their', 'spiritual', 'journey', '.', 'Ancient', 'Chinese', 'tradition', 'contributed', 'significantly', 'to', 'the', 'understanding', 'of', 'energy', 'fields', 'through', 'the', 'concept', 'of', 'qi', '(or', 'chi)', ',', 'meaning', 'vital', 'energy', ',', 'which', 'became', 'central', 'to', 'traditional', 'medicine', 'and', 'martial', 'arts', '.', 'Chinese', 'medicine', 'practitioners', 'and', 'martial', 'artists', 'learned', 'to', 'perceive', 'and', 'manipulate', 'this', 'life', 'force', 'that', 'flows', 'through', 'meridians', 'in', 'the', 'body', ',', 'using', 'it', 'for', 'healing', 'and', 'enhanced', 'physical', 'capabilities', '.', 'This', 'systematic', 'approach', 'to', 'energy', 'work', 'established', 'many', 'of', 'the', 'principles', 'that', 'would', 'later', 'influence', 'modern', 'aura', 'healing', 'practices', '.', 'Similarly', ',', 'ancient', 'Egyptian', 'civilization', 'held', 'beliefs', 'about', 'the', '"ka,', '"', 'representing', 'a', "person's", 'spiritual', 'essence', 'that', 'continued', 'to', 'exist', 'after', 'death', ',', 'while', 'ancient', 'Greeks', 'recognized', 'the', '"aureole,', '"', 'a', 'radiant', 'light', 'surrounding', 'divine', 'figures', 'like', 'gods', 'and', 'heroes', '.', 'Theosophical', 'Influence', 'and', 'Modern', 'Development', 'The', 'modern', 'Western', 'understanding', 'of', 'auras', 'was', 'significantly', 'shaped', 'by', 'the', 'work', 'of', 'Charles', 'Webster', 'Le ...

# %%
len(result)
# Out:
# 2921

# %%
preprocessed_text = result

# %% [markdown]
# ## 2.3 Converting tokens into token ids

# %%
preprocessed_text[:10]
# Out:
# ['The',
#  'Spiritual',
#  'Phenomenon',
#  'of',
#  'Auras',
#  ':',
#  'A',
#  'Comprehensive',
#  'Analysis',
#  'of']

# %%
all_words = sorted(set(preprocessed_text))
all_words
# Out:
# ['"',
#  '"Hands',
#  '"Man',
#  '"Radiant',
#  '"The',
#  '"aureole,',
#  '"ka,',
#  '"phantom',
#  "'",
#  '(chakras',
#  '(energy',
#  '(lohitaka)',
#  '(mañjeṭṭha)',
#  '(nīla)',
#  '(odāta)',
#  '(or',
#  '(pīta)',
#  ')',
#  ',',
#  '.',
#  '1903',
#  '1910',
#  '1980s',
#  '20th',
#  '400',
#  '800',
#  ':',
#  'A',
#  'Additionally',
#  'Advanced',
#  'African',
#  'Age',
#  'American',
#  'Analysis',
#  'Ancient',
#  'Applications',
#  'Astral',
#  'Aura',
#  'Auras',
#  'BCE',
#  'Barbara',
#  'Black',
#  'Blue',
#  'Body',
#  'Brennan',
#  "Brennan's",
#  "Buddha's",
#  'Buddhism',
#  'Buddhist',
#  'Causal',
#  'Cayce',
#  'Celestial',
#  'Chakra',
#  'Charles',
#  'Chinese',
#  'Christina',
#  'Church',
#  'Color',
#  'Comprehensive',
#  'Conclusion',
#  'Connections',
#  'Consciousness',
#  'Contemporary',
#  'Conversely',
#  'Critical',
#  'Cross-Cultural',
#  'Cultural',
#  'Development',
#  'Each',
#  'Eastern',
#  'Edgar',
#  'Egyptian',
#  'Electromagnetic',
#  'Emotional',
#  'Energy',
#  'England',
#  'Etheric',
#  'Explanations',
#  'Field',
#  'Fields',
#  'Flow',
#  'Foundations',
#  'Future',
#  'Gautama',
#  'Greeks',
#  'Green',
#  'Healing',
#  'Her',
#  'Hindu',
#  'His',
#  'Historical',
#  'However',
#  'Human',
#  'In',
#  'India',
#  'Indigenous',
#  'Individuals',
#  'Influence',
#  'Inner',
#  'Integration',
#  'Interpretations',
#  'Invisible',
#  'Its',
#  'Kirlian',
#  'Layers',
#  'Leadbeater',
#  "Leadbeater's",
#  'Life,',
#  'Light,',
#  'Limitations',
#  'Lonsdale',
#  'Manifestations',
#  'Meanings',
#  'Mental',
#  'Modalities',
#  'Modern',
#  'NASA',
#  'Native',
#  'Neurological',
#  'New',
#  'Orange',
#  'Origins',
#  'Perspectives',
#  'Phenomenon',
#  'Photography',
#  'Prabhashvara',
#  'Practices',
#  'Practitioners',
#  'Primary',
#  'Psychological',
#  'Purple',
#  'Rainbow',
#  'Red',
#  'Reiki',
#  'Religious',
#  'Research',
#  'Rudolf',
#  'Scientific',
#  'Seven-Layer',
#  'Significance',
#  'Similarly',
#  'Skeptical',
#  'Society',
#  'Some',
#  'Spiritual',
#  'Steiner',
#  'Structure',
#  'System',
#  'Tantric',
#  'Template',
#  'The',
#  'Theosophical',
#  'These',
#  'This',
#  'Traditional',
#  'Traditions',
#  'Upanishads',
#  'Vedic',
#  'Visible',
#  'Webster',
#  'Wellness',
#  'Western',
#  'When',
#  'Whether',
#  'While',
#  'White',
#  'Yellow',
#  'a',
#  'abilities',
#  'ability',
#  'about',
#  'abundant',
#  'access',
#  'accumulated',
#  'achievement',
#  'across',
#  'action-oriented',
#  'activities',
#  'activity',
#  'actual',
#  'adaptability',
#  'address',
#  'addressing',
#  'adopted',
#  'advanced',
#  'affect',
#  'affected',
#  'after',
#  'aggressive',
#  'ailments',
#  'aim',
#  'all',
#  'allowed',
#  'allows',
#  'also',
#  'alternative',
#  'ambiguous',
#  'an',
#  'analysis',
#  'anatomy',
#  'ancient',
#  'and',
#  'anger',
#  'appear',
#  'appearance',
#  'appearances',
#  'appearing',
#  'appears',
#  'applications',
#  'approach',
#  'approaches',
#  'are',
#  'area',
#  'around',
#  'artists',
#  'arts',
#  'as',
#  'aspects',
#  'assess',
#  'assessments',
#  'associated',
#  'associating',
#  'at',
#  'attempt',
#  'attributed',
#  'aura',
#  "aura's",
#  'aura-based',
#  'aura-related',
#  'auras',
#  'auric',
#  'authentic',
#  'avoiding',
#  'awakened',
#  'awareness',
#  'back',
#  'background',
#  'balance',
#  'balanced',
#  'balancing',
#  'based',
#  'be',
#  'became',
#  'become',
#  'beings',
#  'belief',
#  'beliefs',
#  'believe',
#  'benefits',
#  'between',
#  'beyond',
#  'bias',
#  'bioelectric',
#  'blockages',
#  'blocked',
#  'blue',
#  'bodies',
#  'bodily',
#  'body',
#  'book',
#  'both',
#  'bridge',
#  'bright',
#  'brightness',
#  'brought',
#  'by',
#  'came',
#  'can',
#  'capabilities',
#  'capable',
#  'capture',
#  'careful',
#  'catalyst',
#  'cellular',
#  'centers',
#  'central',
#  'century',
#  'chakra',
#  'chakras',
#  'challenges',
#  'changes',
#  'channels',
#  'characterizing',
#  'charisma',
#  'chi)',
#  'civilization',
#  'civilizations',
#  'claimed',
#  'clairvoyant',
#  'clairvoyants',
#  'clarity',
#  'clean',
#  'cleanse',
#  'cleansing',
#  'closest',
#  'color',
#  'colored',
#  'colorful',
#  'colors',
#  'combine',
#  'combined',
#  'communication',
#  'communities',
#  'compassion',
#  'complementary',
#  'complete',
#  'complex',
#  'component',
#  'comprehensive',
#  'concept',
#  'concepts',
#  'confident',
#  'confirmation',
#  'confirming',
#  'confirms',
#  'connected',
#  'connecting',
#  'connection',
#  'connections',
#  'connects',
#  'consciousness',
#  'considered',
#  'consistency',
#  'consistent',
#  'consisting',
#  'consists',
#  'constitute',
#  'contains',
#  'contaminants',
#  'contemporary',
#  'context',
#  'continued',
#  'continues',
#  'continuously',
#  'contracted',
#  'contribute',
#  'contributed',
#  'contributing',
#  'contribution',
#  'coronal',
#  'correlates',
#  'correspond',
#  'corresponding',
#  'cosmic',
#  'create',
#  'created',
#  'creates',
#  'creating',
#  'creativity',
#  'crimson',
#  'cross-cultural',
#  'cross-modal',
#  'crucial',
#  'crystal',
#  'cultures',
#  'cycles',
#  'daily',
#  'dark',
#  'death',
#  'dedicate',
#  'deep',
#  'deeper',
#  'deficiency',
#  'demonstrate',
#  'demonstrates',
#  'demonstrating',
#  'densest',
#  'depth',
#  'describe',
#  'described',
#  'describes',
#  'describing',
#  'descriptions',
#  'deserves',
#  'designed',
#  'developed',
#  'development',
#  'diagnostic',
#  'different',
#  'dim',
#  'dimensions',
#  'directly',
#  'discharges',
#  'dismissal',
#  'dismissing',
#  'disposition',
#  'distinct',
#  'distinguishing',
#  'diverse',
#  'divine',
#  'document',
#  'documented',
#  'does',
#  'drumming',
#  'due',
#  'during',
#  'dynamic',
#  'each',
#  'earliest',
#  'early',
#  'effect',
#  'electrical',
#  'electromagnetic',
#  'eliminate',
#  'elusive',
#  'emanate',
#  'emanation',
#  'emanations',
#  'embody',
#  'embraced',
#  'emit',
#  'emotion',
#  'emotional',
#  'emotions',
#  'empathetic',
#  'emphasis',
#  'emphasized',
#  'emphasizes',
#  'emphasizing',
#  'encompasses',
#  'encompassing',
#  'enduring',
#  'energetic',
#  'energies',
#  'energy',
#  'enhanced',
#  'enhancement',
#  'enlightened',
#  'enlightenment',
#  'enthusiasm',
#  'entirely',
#  'environmental',
#  'esoteric',
#  'essence',
#  'establish',
#  'established',
#  'establishes',
#  'establishing',
#  'ethereal',
#  'etheric',
#  'evidence',
#  'evolution',
#  'evolving',
#  'exactly',
#  'exhibit',
#  'exist',
#  'existence',
#  'expansive',
#  'expectations',
#  'experience',
#  'experiences',
#  'exploration',
#  'explore',
#  'exploring',
#  'extending',
#  'extends',
#  'facilitating',
#  'fact',
#  'factors',
#  'fails',
#  'far',
#  'fascination',
#  'fatigue',
#  'feelings',
#  'field',
#  'fields',
#  'figures',
#  'filled',
#  'findings',
#  'finds',
#  'first',
#  'five',
#  'flow',
#  'flows',
#  'focus',
#  'focused',
#  'for',
#  'force',
#  'forces',
#  'form',
#  'former',
#  'forms',
#  'found',
#  'foundation',
#  'foundational',
#  'fourth',
#  'framework',
#  'frequencies',
#  'frequently',
#  'from',
#  'function',
#  'functioning',
#  'fundamental',
#  'gained',
#  'gap',
#  'generate',
#  'genuinely',
#  'glands',
#  'gods',
#  'golden',
#  'gray',
#  'grounding',
#  'growth',
#  'guide',
#  'guided',
#  'guides',
#  'handling',
#  'hands-on',
#  'harmonious',
#  'harmony',
#  'has',
#  'he',
#  'healers',
#  'healing',
#  'health',
#  'heart',
#  'held',
#  'help',
#  'helped',
#  'her',
#  'herbs',
#  'heroes',
#  'high',
#  'higher',
#  'highlight',
#  'highlighting',
#  'highly',
#  'him',
#  'his',
#  'history',
#  'holistic',
#  'homes',
#  'human',
#  "humanity's",
#  'humidity',
#  'idea',
#  'identify',
#  'illustrated',
#  'images',
#  'imbalanced',
#  'imbalances',
#  'importance',
#  'improvements',
#  'improving',
#  'in',
#  'inches',
#  'including',
#  'incorporate',
#  'incorporated',
#  'incorporating',
#  'increasingly',
#  'indicate',
#  'indicating',
#  'indigenous',
#  'indigo',
#  "individual's",
#  'individuals',
#  'influence',
#  'influenced',
#  'influential',
#  'information',
#  'inherent',
#  'initially',
#  'inner',
#  'innovations',
#  'insight',
#  'insights',
#  'integral',
#  'integrates',
#  'integrating',
#  'integration',
#  'intellectual',
#  'intensity',
#  'interconnected',
#  'interest',
#  'interpret',
#  'interpretation',
#  'interpretations',
#  'interpreted',
#  'intersection',
#  'intimate',
#  'into',
#  'introspective',
#  'intuition',
#  'intuitive',
#  'investigation',
#  'investigations',
#  'invisible',
#  'ionization',
#  'is',
#  'it',
#  'its',
#  'journey',
#  'known',
#  'language',
#  'later',
#  'layer',
#  'layered',
#  'layers',
#  'leaf',
#  'learned',
#  'leaves',
#  'led',
#  'legitimize',
#  'level',
#  'levels',
#  'life',
#  'light',
#  'like',
#  'literal',
#  'lives',
#  'living',
#  'local',
#  'love',
#  'loved',
#  'low-level',
#  'luminous',
#  'mainstream',
#  'maintain',
#  'maintaining',
#  'maintenance',
#  'make',
#  'making',
#  'manifestation',
#  'manifesting',
#  'manipulate',
#  'many',
#  'map',
#  'martial',
#  'materials',
#  'may',
#  'meaning',
#  'meaningful',
#  'means',
#  'measurable',
#  'measurement',
#  'medicine',
#  'meditation',
#  'meditations',
#  'member',
#  'mental',
#  'mentions',
#  'meridians',
#  'merit',
#  'metabolic',
#  'metaphysical',
#  'meters',
#  'methods',
#  'mid-20th',
#  'millions',
#  'mind',
#  'modalities',
#  'modern',
#  'moisture',
#  'moments',
#  'moral',
#  'more',
#  'most',
#  'motivated',
#  'movement',
#  'moving',
#  'muddy',
#  'multi-colored',
#  'multi-layered',
#  'multifaceted',
#  'multiple',
#  'nadis',
#  'natural',
#  'naturally',
#  'nature',
#  'need',
#  'needs',
#  'negativity',
#  'nervous',
#  'neurological',
#  'new',
#  'nonetheless',
#  'not',
#  'notion',
#  'objective',
#  'obscure',
#  'of',
#  'offering',
#  'often',
#  'on',
#  'one',
#  "one's",
#  'ones',
#  'only',
#  'onto',
#  'optimal',
#  'optimally',
#  'optimistic',
#  'or',
#  'orange',
#  'ordinary',
#  'organisms',
#  'organs',
#  'other',
#  'others',
#  'our',
#  'outer',
#  'outward',
#  'overall',
#  'overlap',
#  'overlook',
#  'own',
#  'part',
#  'particularly',
#  'passion',
#  'path',
#  'pathway',
#  'patterns',
#  'people',
#  'perceive',
#  'perceived',
#  'perceiving',
#  'perceptible',
#  'perception',
#  'perceptions',
#  'perfect',
#  'performed',
#  'perhaps',
#  'permanent',
#  'persistent',
#  "person's",
#  'perspective',
#  'phenomena',
#  'phenomenon',
#  'photographic',
#  'photographs',
#  'photography',
#  'physical',
#  'pinnacle',
#  'placebo',
#  'plant-based',
#  'play',
#  'popularity',
#  'positive',
#  'possess',
#  'possible',
#  'potential',
#  'potentially',
#  'practice',
#  'practices',
#  'practitioners',
#  'prana',
#  'predominantly',
#  'presence',
#  'present',
#  'presents',
#  'pressure',
#  'priest',
#  'primarily',
#  'principle',
#  'principles',
#  'processes',
#  'processing',
#  'produced',
#  'professional',
#  'professions',
#  'project',
#  'proliferation',
#  'promote',
#  'propose',
#  'protocols',
#  'provide',
#  'provides',
#  'providing',
#  'psychic',
#  'psychological',
#  'purification',
#  'purifying',
#  'purity',
#  'qi',
#  'qualities',
#  'radiance',
#  'radiant',
#  'radiation',
#  'range',
#  'rather',
#  'realms',
#  'recipients',
#  'recognized',
#  'recognizes',
#  'recorded',
#  'red',
#  'referred',
#  'refined',
#  'reflect',
#  'reflecting',
#  'reflection',
#  'reflects',
#  'regardless',
#  'regular',
#  'reinterpreted',
#  'related',
#  'relationship',
#  'relatively',
#  'release',
#  'relevance',
#  'relevant',
#  'remained',
#  'remains',
#  'removing',
#  'report',
#  'reported',
#  'represent',
#  'representation',
#  'representations',
#  'represented',
#  'representing',
#  'represents',
#  'require',
#  'research',
#  'researchers',
#  'residual',
#  'resins',
#  'rest',
#  'restore',
#  'result',
#  'resurrection',
#  'revealed',
#  'revealing',
#  'reveals',
#  'revolutionary',
#  'rhythms',
#  'rich',
#  'rigor',
#  'rituals',
#  'roles',
#  'root',
#  'sacred',
#  'sapphire',
#  'scarlet',
#  'scientific',
#  'scientifically',
#  'scriptures',
#  'second',
#  'sections',
#  'seeing',
#  'self-reflection',
#  'selves',
#  'send',
#  'sensitive',
#  'sensitives',
#  'sensitivity',
#  'sensory',
#  'serve',
#  'serves',
#  'seven',
#  'seven-layer',
#  'several',
#  'shape',
#  'shaped',
#  'significance',
#  'significant',
#  'significantly',
#  'signify',
#  'simultaneously',
#  'sits',
#  'skin',
#  'smoke',
#  'socially',
#  'sometimes',
#  'sophisticated',
#  'sound',
#  'spaces',
#  'specific',
#  'specifically',
#  'spinning',
#  'spirit',
#  'spiritual',
#  'spirituality',
#  'spiritually',
#  'stages',
#  'stagnant',
#  'state',
#  'states',
#  'stochastic',
#  'strengthen',
#  'stress',
#  'strong',
#  'study',
#  'subjective',
#  'subsequent',
#  'subsequently',
#  'subtle',
#  'such',
#  'suggest',
#  'suggesting',
#  'suggests',
#  'sunny',
#  'sunrise',
#  'sunset',
#  'support',
#  'supporting',
#  'surface',
#  'surrounding',
#  'symbol',
#  'symbolic',
#  'symbolizing',
#  'synesthesia',
#  'synthesis',
#  'system',
#  'systematic',
#  'tapestry',
#  'teach',
#  'techniques',
#  'tendencies',
#  'tendency',
#  'texts',
#  'than',
#  'that',
#  'the',
#  'their',
#  'them',
#  'themselves',
#  'theory',
#  'theosophical',
#  'theosophists',
#  'therapeutic',
#  'therapy',
#  'these',
#  'they',
#  'third',
#  'this',
#  'though',
#  'thoughts',
#  'thousands',
#  'three',
#  'through',
#  'throughout',
#  'timing',
#  'to',
#  'tool',
#  'torn',
#  'tradition',
#  'traditional',
#  'traditionally',
#  'traditions',
#  'trained',
#  'transformation',
#  'transformative',
#  'truth',
#  'two',
#  'typically',
#  'ultimate',
#  'unconditional',
#  'understanding',
#  'understood',
#  'unestablished',
#  'unified',
#  'unique',
#  'unresolved',
#  'until',
#  'up',
#  'upper',
#  'use',
#  'using',
#  'utilize',
#  'utilizing',
#  'validate',
#  'validating',
#  'validity',
#  'valuable',
#  'variations',
#  'various',
#  'vibrate',
#  'vibrating',
#  'vibrations',
#  'viewing',
#  'virtues',
#  'visible',
#  'visual',
#  'visualization',
#  'vital',
#  'vitality',
#  'vortices',
#  'was',
#  'weddings',
#  'well-being',
#  'wellness',
#  'were',
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'white',
#  'who',
#  'wisdom',
#  'wise',
#  'with',
#  'within',
#  'without',
#  'woods',
#  'work',
#  'working',
#  'works',
#  ...]

# %%
vocab_size = len(all_words)
print(vocab_size)
# Out:
# 1007

# %%
vocab = {token:integer for integer,token in enumerate(all_words)}

vocab
# Out:
# {'"': 0,
#  '"Hands': 1,
#  '"Man': 2,
#  '"Radiant': 3,
#  '"The': 4,
#  '"aureole,': 5,
#  '"ka,': 6,
#  '"phantom': 7,
#  "'": 8,
#  '(chakras': 9,
#  '(energy': 10,
#  '(lohitaka)': 11,
#  '(mañjeṭṭha)': 12,
#  '(nīla)': 13,
#  '(odāta)': 14,
#  '(or': 15,
#  '(pīta)': 16,
#  ')': 17,
#  ',': 18,
#  '.': 19,
#  '1903': 20,
#  '1910': 21,
#  '1980s': 22,
#  '20th': 23,
#  '400': 24,
#  '800': 25,
#  ':': 26,
#  'A': 27,
#  'Additionally': 28,
#  'Advanced': 29,
#  'African': 30,
#  'Age': 31,
#  'American': 32,
#  'Analysis': 33,
#  'Ancient': 34,
#  'Applications': 35,
#  'Astral': 36,
#  'Aura': 37,
#  'Auras': 38,
#  'BCE': 39,
#  'Barbara': 40,
#  'Black': 41,
#  'Blue': 42,
#  'Body': 43,
#  'Brennan': 44,
#  "Brennan's": 45,
#  "Buddha's": 46,
#  'Buddhism': 47,
#  'Buddhist': 48,
#  'Causal': 49,
#  'Cayce': 50,
#  'Celestial': 51,
#  'Chakra': 52,
#  'Charles': 53,
#  'Chinese': 54,
#  'Christina': 55,
#  'Church': 56,
#  'Color': 57,
#  'Comprehensive': 58,
#  'Conclusion': 59,
#  'Connections': 60,
#  'Consciousness': 61,
#  'Contemporary': 62,
#  'Conversely': 63,
#  'Critical': 64,
#  'Cross-Cultural': 65,
#  'Cultural': 66,
#  'Development': 67,
#  'Each': 68,
#  'Eastern': 69,
#  'Edgar': 70,
#  'Egyptian': 71,
#  'Electromagnetic': 72,
#  'Emotional': 73,
#  'Energy': 74,
#  'England': 75,
#  'Etheric': 76,
#  'Explanations': 77,
#  'Field': 78,
#  'Fields': 79,
#  'Flow': 80,
#  'Foundations': 81,
#  'Future': 82,
#  'Gautama': 83,
#  'Greeks': 84,
#  'Green': 85,
#  'Healing': 86,
#  'Her': 87,
#  'Hindu': 88,
#  'His': 89,
#  'Historical': 90,
#  'However': 91,
#  'Human': 92,
#  'In': 93,
#  'India': 94,
#  'Indigenous': 95,
#  'Individuals': 96,
#  'Influence': 97,
#  'Inner': 98,
#  'Integration': 99,
#  'Interpretations': 100,
#  'Invisible': 101,
#  'Its': 102,
#  'Kirlian': 103,
#  'Layers': 104,
#  'Leadbeater': 105,
#  "Leadbeater's": 106,
#  'Life,': 107,
#  'Light,': 108,
#  'Limitations': 109,
#  'Lonsdale': 110,
#  'Manifestations': 111,
#  'Meanings': 112,
#  'Mental': 113,
#  'Modalities': 114,
#  'Modern': 115,
#  'NASA': 116,
#  'Native': 117,
#  'Neurological': 118,
#  'New': 119,
#  'Orange': 120,
#  'Origins': 121,
#  'Perspectives': 122,
#  'Phenomenon': 123,
#  'Photography': 124,
#  'Prabhashvara': 125,
#  'Practices': 126,
#  'Practitioners': 127,
#  'Primary': 128,
#  'Psychological': 129,
#  'Purple': 130,
#  'Rainbow': 131,
#  'Red': 132,
#  'Reiki': 133,
#  'Religious': 134,
#  'Research': 135,
#  'Rudolf': 136,
#  'Scientific': 137,
#  'Seven-Layer': 138,
#  'Significance': 139,
#  'Similarly': 140,
#  'Skeptical': 141,
#  'Society': 142,
#  'Some': 143,
#  'Spiritual': 144,
#  'Steiner': 145,
#  'Structure': 146,
#  'System': 147,
#  'Tantric': 148,
#  'Template': 149,
#  'The': 150,
#  'Theosophical': 151,
#  'These': 152,
#  'This': 153,
#  'Traditional': 154,
#  'Traditions': 155,
#  'Upanishads': 156,
#  'Vedic': 157,
#  'Visible': 158,
#  'Webster': 159,
#  'Wellness': 160,
#  'Western': 161,
#  'When': 162,
#  'Whether': 163,
#  'While': 164,
#  'White': 165,
#  'Yellow': 166,
#  'a': 167,
#  'abilities': 168,
#  'ability': 169,
#  'about': 170,
#  'abundant': 171,
#  'access': 172,
#  'accumulated': 173,
#  'achievement': 174,
#  'across': 175,
#  'action-oriented': 176,
#  'activities': 177,
#  'activity': 178,
#  'actual': 179,
#  'adaptability': 180,
#  'address': 181,
#  'addressing': 182,
#  'adopted': 183,
#  'advanced': 184,
#  'affect': 185,
#  'affected': 186,
#  'after': 187,
#  'aggressive': 188,
#  'ailments': 189,
#  'aim': 190,
#  'all': 191,
#  'allowed': 192,
#  'allows': 193,
#  'also': 194,
#  'alternative': 195,
#  'ambiguous': 196,
#  'an': 197,
#  'analysis': 198,
#  'anatomy': 199,
#  'ancient': 200,
#  'and': 201,
#  'anger': 202,
#  'appear': 203,
#  'appearance': 204,
#  'appearances': 205,
#  'appearing': 206,
#  'appears': 207,
#  'applications': 208,
#  'approach': 209,
#  'approaches': 210,
#  'are': 211,
#  'area': 212,
#  'around': 213,
#  'artists': 214,
#  'arts': 215,
#  'as': 216,
#  'aspects': 217,
#  'assess': 218,
#  'assessments': 219,
#  'associated': 220,
#  'associating': 221,
#  'at': 222,
#  'attempt': 223,
#  'attributed': 224,
#  'aura': 225,
#  "aura's": 226,
#  'aura-based': 227,
#  'aura-related': 228,
#  'auras': 229,
#  'auric': 230,
#  'authentic': 231,
#  'avoiding': 232,
#  'awakened': 233,
#  'awareness': 234,
#  'back': 235,
#  'background': 236,
#  'balance': 237,
#  'balanced': 238,
#  'balancing': 239,
#  'based': 240,
#  'be': 241,
#  'became': 242,
#  'become': 243,
#  'beings': 244,
#  'belief': 245,
#  'beliefs': 246,
#  'believe': 247,
#  'benefits': 248,
#  'between': 249,
#  'beyond': 250,
#  'bias': 251,
#  'bioelectric': 252,
#  'blockages': 253,
#  'blocked': 254,
#  'blue': 255,
#  'bodies': 256,
#  'bodily': 257,
#  'body': 258,
#  'book': 259,
#  'both': 260,
#  'bridge': 261,
#  'bright': 262,
#  'brightness': 263,
#  'brought': 264,
#  'by': 265,
#  'came': 266,
#  'can': 267,
#  'capabilities': 268,
#  'capable': 269,
#  'capture': 270,
#  'careful': 271,
#  'catalyst': 272,
#  'cellular': 273,
#  'centers': 274,
#  'central': 275,
#  'century': 276,
#  'chakra': 277,
#  'chakras': 278,
#  'challenges': 279,
#  'changes': 280,
#  'channels': 281,
#  'characterizing': 282,
#  'charisma': 283,
#  'chi)': 284,
#  'civilization': 285,
#  'civilizations': 286,
#  'claimed': 287,
#  'clairvoyant': 288,
#  'clairvoyants': 289,
#  'clarity': 290,
#  'clean': 291,
#  'cleanse': 292,
#  'cleansing': 293,
#  'closest': 294,
#  'color': 295,
#  'colored': 296,
#  'colorful': 297,
#  'colors': 298,
#  'combine': 299,
#  'combined': 300,
#  'communication': 301,
#  'communities': 302,
#  'compassion': 303,
#  'complementary': 304,
#  'complete': 305,
#  'complex': 306,
#  'component': 307,
#  'comprehensive': 308,
#  'concept': 309,
#  'concepts': 310,
#  'confident': 311,
#  'confirmation': 312,
#  'confirming': 313,
#  'confirms': 314,
#  'connected': 315,
#  'connecting': 316,
#  'connection': 317,
#  'connections': 318,
#  'connects': 319,
#  'consciousness': 320,
#  'considered': 321,
#  'consistency': 322,
#  'consistent': 323,
#  'consisting': 324,
#  'consists': 325,
#  'constitute': 326,
#  'contains': 327,
#  'contaminants': 328,
#  'contemporary': 329,
#  'context': 330,
#  'continued': 331,
#  'continues': 332,
#  'continuously': 333,
#  'contracted': 334,
#  'contribute': 335,
#  'contributed': 336,
#  'contributing': 337,
#  'contribution': 338,
#  'coronal': 339,
#  'correlates': 340,
#  'correspond': 341,
#  'corresponding': 342,
#  'cosmic': 343,
#  'create': 344,
#  'created': 345,
#  'creates': 346,
#  'creating': 347,
#  'creativity': 348,
#  'crimson': 349,
#  'cross-cultural': 350,
#  'cross-modal': 351,
#  'crucial': 352,
#  'crystal': 353,
#  'cultures': 354,
#  'cycles': 355,
#  'daily': 356,
#  'dark': 357,
#  'death': 358,
#  'dedicate': 359,
#  'deep': 360,
#  'deeper': 361,
#  'deficiency': 362,
#  'demonstrate': 363,
#  'demonstrates': 364,
#  'demonstrating': 365,
#  'densest': 366,
#  'depth': 367,
#  'describe': 368,
#  'described': 369,
#  'describes': 370,
#  'describing': 371,
#  'descriptions': 372,
#  'deserves': 373,
#  'designed': 374,
#  'developed': 375,
#  'development': 376,
#  'diagnostic': 377,
#  'different': 378,
#  'dim': 379,
#  'dimensions': 380,
#  'directly': 381,
#  'discharges': 382,
#  'dismissal': 383,
#  'dismissing': 384,
#  'disposition': 385,
#  'distinct': 386,
#  'distinguishing': 387,
#  'diverse': 388,
#  'divine': 389,
#  'document': 390,
#  'documented': 391,
#  'does': 392,
#  'drumming': 393,
#  'due': 394,
#  'during': 395,
#  'dynamic': 396,
#  'each': 397,
#  'earliest': 398,
#  'early': 399,
#  'effect': 400,
#  'electrical': 401,
#  'electromagnetic': 402,
#  'eliminate': 403,
#  'elusive': 404,
#  'emanate': 405,
#  'emanation': 406,
#  'emanations': 407,
#  'embody': 408,
#  'embraced': 409,
#  'emit': 410,
#  'emotion': 411,
#  'emotional': 412,
#  'emotions': 413,
#  'empathetic': 414,
#  'emphasis': 415,
#  'emphasized': 416,
#  'emphasizes': 417,
#  'emphasizing': 418,
#  'encompasses': 419,
#  'encompassing': 420,
#  'enduring': 421,
#  'energetic': 422,
#  'energies': 423,
#  'energy': 424,
#  'enhanced': 425,
#  'enhancement': 426,
#  'enlightened': 427,
#  'enlightenment': 428,
#  'enthusiasm': 429,
#  'entirely': 430,
#  'environmental': 431,
#  'esoteric': 432,
#  'essence': 433,
#  'establish': 434,
#  'established': 435,
#  'establishes': 436,
#  'establishing': 437,
#  'ethereal': 438,
#  'etheric': 439,
#  'evidence': 440,
#  'evolution': 441,
#  'evolving': 442,
#  'exactly': 443,
#  'exhibit': 444,
#  'exist': 445,
#  'existence': 446,
#  'expansive': 447,
#  'expectations': 448,
#  'experience': 449,
#  'experiences': 450,
#  'exploration': 451,
#  'explore': 452,
#  'exploring': 453,
#  'extending': 454,
#  'extends': 455,
#  'facilitating': 456,
#  'fact': 457,
#  'factors': 458,
#  'fails': 459,
#  'far': 460,
#  'fascination': 461,
#  'fatigue': 462,
#  'feelings': 463,
#  'field': 464,
#  'fields': 465,
#  'figures': 466,
#  'filled': 467,
#  'findings': 468,
#  'finds': 469,
#  'first': 470,
#  'five': 471,
#  'flow': 472,
#  'flows': 473,
#  'focus': 474,
#  'focused': 475,
#  'for': 476,
#  'force': 477,
#  'forces': 478,
#  'form': 479,
#  'former': 480,
#  'forms': 481,
#  'found': 482,
#  'foundation': 483,
#  'foundational': 484,
#  'fourth': 485,
#  'framework': 486,
#  'frequencies': 487,
#  'frequently': 488,
#  'from': 489,
#  'function': 490,
#  'functioning': 491,
#  'fundamental': 492,
#  'gained': 493,
#  'gap': 494,
#  'generate': 495,
#  'genuinely': 496,
#  'glands': 497,
#  'gods': 498,
#  'golden': 499,
#  'gray': 500,
#  'grounding': 501,
#  'growth': 502,
#  'guide': 503,
#  'guided': 504,
#  'guides': 505,
#  'handling': 506,
#  'hands-on': 507,
#  'harmonious': 508,
#  'harmony': 509,
#  'has': 510,
#  'he': 511,
#  'healers': 512,
#  'healing': 513,
#  'health': 514,
#  'heart': 515,
#  'held': 516,
#  'help': 517,
#  'helped': 518,
#  'her': 519,
#  'herbs': 520,
#  'heroes': 521,
#  'high': 522,
#  'higher': 523,
#  'highlight': 524,
#  'highlighting': 525,
#  'highly': 526,
#  'him': 527,
#  'his': 528,
#  'history': 529,
#  'holistic': 530,
#  'homes': 531,
#  'human': 532,
#  "humanity's": 533,
#  'humidity': 534,
#  'idea': 535,
#  'identify': 536,
#  'illustrated': 537,
#  'images': 538,
#  'imbalanced': 539,
#  'imbalances': 540,
#  'importance': 541,
#  'improvements': 542,
#  'improving': 543,
#  'in': 544,
#  'inches': 545,
#  'including': 546,
#  'incorporate': 547,
#  'incorporated': 548,
#  'incorporating': 549,
#  'increasingly': 550,
#  'indicate': 551,
#  'indicating': 552,
#  'indigenous': 553,
#  'indigo': 554,
#  "individual's": 555,
#  'individuals': 556,
#  'influence': 557,
#  'influenced': 558,
#  'influential': 559,
#  'information': 560,
#  'inherent': 561,
#  'initially': 562,
#  'inner': 563,
#  'innovations': 564,
#  'insight': 565,
#  'insights': 566,
#  'integral': 567,
#  'integrates': 568,
#  'integrating': 569,
#  'integration': 570,
#  'intellectual': 571,
#  'intensity': 572,
#  'interconnected': 573,
#  'interest': 574,
#  'interpret': 575,
#  'interpretation': 576,
#  'interpretations': 577,
#  'interpreted': 578,
#  'intersection': 579,
#  'intimate': 580,
#  'into': 581,
#  'introspective': 582,
#  'intuition': 583,
#  'intuitive': 584,
#  'investigation': 585,
#  'investigations': 586,
#  'invisible': 587,
#  'ionization': 588,
#  'is': 589,
#  'it': 590,
#  'its': 591,
#  'journey': 592,
#  'known': 593,
#  'language': 594,
#  'later': 595,
#  'layer': 596,
#  'layered': 597,
#  'layers': 598,
#  'leaf': 599,
#  'learned': 600,
#  'leaves': 601,
#  'led': 602,
#  'legitimize': 603,
#  'level': 604,
#  'levels': 605,
#  'life': 606,
#  'light': 607,
#  'like': 608,
#  'literal': 609,
#  'lives': 610,
#  'living': 611,
#  'local': 612,
#  'love': 613,
#  'loved': 614,
#  'low-level': 615,
#  'luminous': 616,
#  'mainstream': 617,
#  'maintain': 618,
#  'maintaining': 619,
#  'maintenance': 620,
#  'make': 621,
#  'making': 622,
#  'manifestation': 623,
#  'manifesting': 624,
#  'manipulate': 625,
#  'many': 626,
#  'map': 627,
#  'martial': 628,
#  'materials': 629,
#  'may': 630,
#  'meaning': 631,
#  'meaningful': 632,
#  'means': 633,
#  'measurable': 634,
#  'measurement': 635,
#  'medicine': 636,
#  'meditation': 637,
#  'meditations': 638,
#  'member': 639,
#  'mental': 640,
#  'mentions': 641,
#  'meridians': 642,
#  'merit': 643,
#  'metabolic': 644,
#  'metaphysical': 645,
#  'meters': 646,
#  'methods': 647,
#  'mid-20th': 648,
#  'millions': 649,
#  'mind': 650,
#  'modalities': 651,
#  'modern': 652,
#  'moisture': 653,
#  'moments': 654,
#  'moral': 655,
#  'more': 656,
#  'most': 657,
#  'motivated': 658,
#  'movement': 659,
#  'moving': 660,
#  'muddy': 661,
#  'multi-colored': 662,
#  'multi-layered': 663,
#  'multifaceted': 664,
#  'multiple': 665,
#  'nadis': 666,
#  'natural': 667,
#  'naturally': 668,
#  'nature': 669,
#  'need': 670,
#  'needs': 671,
#  'negativity': 672,
#  'nervous': 673,
#  'neurological': 674,
#  'new': 675,
#  'nonetheless': 676,
#  'not': 677,
#  'notion': 678,
#  'objective': 679,
#  'obscure': 680,
#  'of': 681,
#  'offering': 682,
#  'often': 683,
#  'on': 684,
#  'one': 685,
#  "one's": 686,
#  'ones': 687,
#  'only': 688,
#  'onto': 689,
#  'optimal': 690,
#  'optimally': 691,
#  'optimistic': 692,
#  'or': 693,
#  'orange': 694,
#  'ordinary': 695,
#  'organisms': 696,
#  'organs': 697,
#  'other': 698,
#  'others': 699,
#  'our': 700,
#  'outer': 701,
#  'outward': 702,
#  'overall': 703,
#  'overlap': 704,
#  'overlook': 705,
#  'own': 706,
#  'part': 707,
#  'particularly': 708,
#  'passion': 709,
#  'path': 710,
#  'pathway': 711,
#  'patterns': 712,
#  'people': 713,
#  'perceive': 714,
#  'perceived': 715,
#  'perceiving': 716,
#  'perceptible': 717,
#  'perception': 718,
#  'perceptions': 719,
#  'perfect': 720,
#  'performed': 721,
#  'perhaps': 722,
#  'permanent': 723,
#  'persistent': 724,
#  "person's": 725,
#  'perspective': 726,
#  'phenomena': 727,
#  'phenomenon': 728,
#  'photographic': 729,
#  'photographs': 730,
#  'photography': 731,
#  'physical': 732,
#  'pinnacle': 733,
#  'placebo': 734,
#  'plant-based': 735,
#  'play': 736,
#  'popularity': 737,
#  'positive': 738,
#  'possess': 739,
#  'possible': 740,
#  'potential': 741,
#  'potentially': 742,
#  'practice': 743,
#  'practices': 744,
#  'practitioners': 745,
#  'prana': 746,
#  'predominantly': 747,
#  'presence': 748,
#  'present': 749,
#  'presents': 750,
#  'pressure': 751,
#  'priest': 752,
#  'primarily': 753,
#  'principle': 754,
#  'principles': 755,
#  'processes': 756,
#  'processing': 757,
#  'produced': 758,
#  'professional': 759,
#  'professions': 760,
#  'project': 761,
#  'proliferation': 762,
#  'promote': 763,
#  'propose': 764,
#  'protocols': 765,
#  'provide': 766,
#  'provides': 767,
#  'providing': 768,
#  'psychic': 769,
#  'psychological': 770,
#  'purification': 771,
#  'purifying': 772,
#  'purity': 773,
#  'qi': 774,
#  'qualities': 775,
#  'radiance': 776,
#  'radiant': 777,
#  'radiation': 778,
#  'range': 779,
#  'rather': 780,
#  'realms': 781,
#  'recipients': 782,
#  'recognized': 783,
#  'recognizes': 784,
#  'recorded': 785,
#  'red': 786,
#  'referred': 787,
#  'refined': 788,
#  'reflect': 789,
#  'reflecting': 790,
#  'reflection': 791,
#  'reflects': 792,
#  'regardless': 793,
#  'regular': 794,
#  'reinterpreted': 795,
#  'related': 796,
#  'relationship': 797,
#  'relatively': 798,
#  'release': 799,
#  'relevance': 800,
#  'relevant': 801,
#  'remained': 802,
#  'remains': 803,
#  'removing': 804,
#  'report': 805,
#  'reported': 806,
#  'represent': 807,
#  'representation': 808,
#  'representations': 809,
#  'represented': 810,
#  'representing': 811,
#  'represents': 812,
#  'require': 813,
#  'research': 814,
#  'researchers': 815,
#  'residual': 816,
#  'resins': 817,
#  'rest': 818,
#  'restore': 819,
#  'result': 820,
#  'resurrection': 821,
#  'revealed': 822,
#  'revealing': 823,
#  'reveals': 824,
#  'revolutionary': 825,
#  'rhythms': 826,
#  'rich': 827,
#  'rigor': 828,
#  'rituals': 829,
#  'roles': 830,
#  'root': 831,
#  'sacred': 832,
#  'sapphire': 833,
#  'scarlet': 834,
#  'scientific': 835,
#  'scientifically': 836,
#  'scriptures': 837,
#  'second': 838,
#  'sections': 839,
#  'seeing': 840,
#  'self-reflection': 841,
#  'selves': 842,
#  'send': 843,
#  'sensitive': 844,
#  'sensitives': 845,
#  'sensitivity': 846,
#  'sensory': 847,
#  'serve': 848,
#  'serves': 849,
#  'seven': 850,
#  'seven-layer': 851,
#  'several': 852,
#  'shape': 853,
#  'shaped': 854,
#  'significance': 855,
#  'significant': 856,
#  'significantly': 857,
#  'signify': 858,
#  'simultaneously': 859,
#  'sits': 860,
#  'skin': 861,
#  'smoke': 862,
#  'socially': 863,
#  'sometimes': 864,
#  'sophisticated': 865,
#  'sound': 866,
#  'spaces': 867,
#  'specific': 868,
#  'specifically': 869,
#  'spinning': 870,
#  'spirit': 871,
#  'spiritual': 872,
#  'spirituality': 873,
#  'spiritually': 874,
#  'stages': 875,
#  'stagnant': 876,
#  'state': 877,
#  'states': 878,
#  'stochastic': 879,
#  'strengthen': 880,
#  'stress': 881,
#  'strong': 882,
#  'study': 883,
#  'subjective': 884,
#  'subsequent': 885,
#  'subsequently': 886,
#  'subtle': 887,
#  'such': 888,
#  'suggest': 889,
#  'suggesting': 890,
#  'suggests': 891,
#  'sunny': 892,
#  'sunrise': 893,
#  'sunset': 894,
#  'support': 895,
#  'supporting': 896,
#  'surface': 897,
#  'surrounding': 898,
#  'symbol': 899,
#  'symbolic': 900,
#  'symbolizing': 901,
#  'synesthesia': 902,
#  'synthesis': 903,
#  'system': 904,
#  'systematic': 905,
#  'tapestry': 906,
#  'teach': 907,
#  'techniques': 908,
#  'tendencies': 909,
#  'tendency': 910,
#  'texts': 911,
#  'than': 912,
#  'that': 913,
#  'the': 914,
#  'their': 915,
#  'them': 916,
#  'themselves': 917,
#  'theory': 918,
#  'theosophical': 919,
#  'theosophists': 920,
#  'therapeutic': 921,
#  'therapy': 922,
#  'these': 923,
#  'they': 924,
#  'third': 925,
#  'this': 926,
#  'though': 927,
#  'thoughts': 928,
#  'thousands': 929,
#  'three': 930,
#  'through': 931,
#  'throughout': 932,
#  'timing': 933,
#  'to': 934,
#  'tool': 935,
#  'torn': 936,
#  'tradition': 937,
#  'traditional': 938,
#  'traditionally': 939,
#  'traditions': 940,
#  'trained': 941,
#  'transformation': 942,
#  'transformative': 943,
#  'truth': 944,
#  'two': 945,
#  'typically': 946,
#  'ultimate': 947,
#  'unconditional': 948,
#  'understanding': 949,
#  'understood': 950,
#  'unestablished': 951,
#  'unified': 952,
#  'unique': 953,
#  'unresolved': 954,
#  'until': 955,
#  'up': 956,
#  'upper': 957,
#  'use': 958,
#  'using': 959,
#  'utilize': 960,
#  'utilizing': 961,
#  'validate': 962,
#  'validating': 963,
#  'validity': 964,
#  'valuable': 965,
#  'variations': 966,
#  'various': 967,
#  'vibrate': 968,
#  'vibrating': 969,
#  'vibrations': 970,
#  'viewing': 971,
#  'virtues': 972,
#  'visible': 973,
#  'visual': 974,
#  'visualization': 975,
#  'vital': 976,
#  'vitality': 977,
#  'vortices': 978,
#  'was': 979,
#  'weddings': 980,
#  'well-being': 981,
#  'wellness': 982,
#  'were': 983,
#  'what': 984,
#  'when': 985,
#  'where': 986,
#  'which': 987,
#  'while': 988,
#  'white': 989,
#  'who': 990,
#  'wisdom': 991,
#  'wise': 992,
#  'with': 993,
#  'within': 994,
#  'without': 995,
#  'woods': 996,
#  'work': 997,
#  'working': 998,
#  'works': 999,
#  ...}

# %%
class SimpleTokenizerV1:
    def __init__(self,vocab):
        self.str_to_int = vocab 
        self.int_to_str = {i:s for s,i in vocab.items()}
        
    def encode(self,text):
        preprocessed = re.split(r'([,.:;?_!"()\']|--|\s)',text)
        
        preprocessed = [
            item.strip() for item in preprocessed if item.strip()
        ] 
        
        ids = [self.str_to_int[s] for s in preprocessed]
        return ids
    
    
    def decode(self, ids) :
        text = " ".join([self.int_to_str[i]for i in ids])
        # Replace spaces before the specified punctuations 
        text = re.sub(r'\s+([,.?!"()\'])',r'\1',text) 
        return text

# %%
tokenizer = SimpleTokenizerV1(vocab)

text = " Chakra Connections and Energy Flow"

ids = tokenizer.encode(text)
ids
# Out:
# [52, 60, 201, 74, 80]

# %%
print(tokenizer.decode(ids))
# Out:
# Chakra Connections and Energy Flow

# %% [markdown]
# ## 2.4 Adding Special context tokens

# %%
## lets modify  the vocabulary to include these two special tokens , <unk> and <|endoftext|> , by adding them to our list of all unique words 

all_tokens = sorted(list(set(preprocessed_text)))
all_tokens.extend(["<|endoftext|>" , "<|unk|>"])

vocab = {token :integer for integer,token in enumerate(all_tokens)}

print(len(vocab.items()))
# Out:
# 1009

# %%
for i,item in enumerate(list(vocab.items())[-5:]):
    print(item)
# Out:
# ('yellow', 1004)
# ('yoga', 1005)
# ('–', 1006)
# ('<|endoftext|>', 1007)
# ('<|unk|>', 1008)

# %%
class SimpleTokenizerV2:
    def __init__(self,vocab):
        self.str_to_int = vocab 
        self.int_to_str = {i:s for s,i in vocab.items()}
        
    def encode(self,text):
        preprocessed = re.split(r'([,.:;?_!"()\']|--|\s)',text)
        
        preprocessed = [
            item.strip() for item in preprocessed if item.strip()
        ] 
        preprocessed = [item if item in self.str_to_int else "<|unk|>" for item in preprocessed]
        ids = [self.str_to_int[s] for s in preprocessed]
        return ids
    
    
    def decode(self, ids) :
        text = " ".join([self.int_to_str[i]for i in ids])
        # Replace spaces before the specified punctuations 
        text = re.sub(r'\s+([,.?!"()\'])',r'\1',text) 
        return text

# %%
text1 = "Helllo do you love games ?"
text2 = "in the spiritual essence chakra wins."
text  = "<|endoftext|>".join((text1,text2))
print(text)
# Out:
# Helllo do you love games ?<|endoftext|>in the spiritual essence chakra wins.

# %%
tokenizer_v2 = SimpleTokenizerV2(vocab)
res = tokenizer_v2.encode(text)

# %%
tokenizer_v2.decode(res)
# Out:
# '<|unk|> <|unk|> <|unk|> love <|unk|> <|unk|> <|unk|> the spiritual essence chakra <|unk|>.'

# %% [markdown]
# ## additional special tokens : [BOS] , [EOS] , [PAD]

# %% [markdown]
# # Byte Pair Encoding

# %%
from importlib.metadata import version 
import tiktoken 
print("tiktoken version: ",version("tiktoken"))
# Out:
# tiktoken version:  0.8.0

# %%
tik_tokenizer = tiktoken.get_encoding("gpt2")

text =  ("Hello , do you love the reading books  <|endoftext|> In the sunluight terraces of someunknown Place. ")

integers = tik_tokenizer.encode( text,allowed_special={"<|endoftext|>"})
print(integers)
# Out:
# [15496, 837, 466, 345, 1842, 262, 3555, 3835, 220, 220, 50256, 554, 262, 4252, 2290, 432, 8812, 2114, 286, 617, 34680, 8474, 13, 220]

# %% [markdown]
# ## 2.6 Data sampling with a Sliding window

# %%
senten = tik_tokenizer.decode(integers)
print(senten)
# Out:
# Hello , do you love the reading books  <|endoftext|> In the sunluight terraces of someunknown Place.

# %%
# llms work by predicting the next token one at a time 

with open(file_path,"r",encoding="utf-8") as f :
    raw_text = f.read()
raw_text
# Out:
# 'The Spiritual Phenomenon of Auras: A Comprehensive Analysis of Energy Fields in Human Consciousness\nThe concept of auras represents one of humanity\'s most enduring spiritual beliefs, encompassing the idea that all living beings emanate subtle energy fields that can be perceived, interpreted, and influenced through various practices. This luminous radiation, described across cultures as a colored emanation surrounding the human body, serves as a bridge between the physical and metaphysical realms, offering insights into an individual\'s emotional, mental, and spiritual states. The study of auras reveals a rich tapestry of cross-cultural spiritual wisdom, from ancient Hindu scriptures to modern New Age practices, demonstrating humanity\'s persistent fascination with the invisible forces that shape our existence and consciousness.\n\nHistorical and Cultural Foundations\nAncient Origins and Cross-Cultural Manifestations\nThe belief in auras extends far back into human history, with documented evidence appearing in various ancient civilizations and spiritual traditions. In ancient India, the concept finds its earliest recorded mentions in the Hindu scriptures known as the Upanishads, written between 800 and 400 BCE, which describe the concept of prana, or life force energy. These sacred texts teach that prana flows through all living beings and can be perceived through meditation and spiritual practices, manifesting as an aura that reflects an individual\'s spiritual development and vital essence. The Upanishads establish the foundational understanding that this energy field serves as a visible representation of one\'s inner spiritual state, providing a means for advanced practitioners to assess and guide others on their spiritual journey.\n\nAncient Chinese tradition contributed significantly to the understanding of energy fields through the concept of qi (or chi), meaning vital energy, which became central to traditional medicine and martial arts. Chinese medicine practitioners and martial artists learned to perceive and manipulate this life force that flows through meridians in the body, using it for healing and enhanced physical capabilities. This systematic approach to energy work established many of the principles that would later influence modern aura healing practices. Similarly, ancient Egyptian civilization held beliefs about the "ka," representing a person\'s spiritual essence that continued to exist after death, while ancient Greeks recognized the "aureole," a radiant light surrounding divine figures like gods and heroes.\n\nTheosophical Influence and Modern Development\nThe modern Western understanding of auras was significantly shaped by the work of Charles Webster Leadbeater, a former Church of England priest and member of the Theosophical Society in the early 20th century. Leadbeater claimed to possess clairvoyant abilities that allowed him to make scientific investigations of the human energy field, and his 1903 book "Man Visible and Invisible" illustrated the aura at various stages of human moral evolution. His revolutionary contribution came in 1910 with "The Inner Life," where he incorporated the Tantric notion of chakras, describing them as energy vortices and associating each with specific glands and organs. This synthesis of Eastern and Western esoteric traditions created the foundation for contemporary aura theory.\n\nLeadbeater\'s innovations were subsequently adopted and reinterpreted by other influential theosophists such as Rudolf Steiner and Edgar Cayce, though the concept remained relatively obscure until the 1980s when it was embraced by the New Age movement. This resurrection of interest led to a proliferation of aura-related practices, from aura photography to energy healing modalities, establishing auras as a central component of alternative spirituality. The theosophical interpretation emphasized the multi-layered nature of the aura, with different levels corresponding to various aspects of hum ...

# %%
enc_text = tik_tokenizer.encode(raw_text)
print(len(enc_text))
# Out:
# 3332

# %%
enc_text
# Out:
# [464,
#  33944,
#  34828,
#  3674,
#  261,
#  286,
#  15412,
#  292,
#  25,
#  317,
#  40917,
#  14691,
#  286,
#  6682,
#  23948,
#  287,
#  5524,
#  45595,
#  1108,
#  198,
#  464,
#  3721,
#  286,
#  257,
#  17786,
#  6870,
#  530,
#  286,
#  9265,
#  338,
#  749,
#  24056,
#  8557,
#  9056,
#  11,
#  20504,
#  19696,
#  262,
#  2126,
#  326,
#  477,
#  2877,
#  9791,
#  31184,
#  378,
#  11800,
#  2568,
#  7032,
#  326,
#  460,
#  307,
#  11067,
#  11,
#  16173,
#  11,
#  290,
#  12824,
#  832,
#  2972,
#  6593,
#  13,
#  770,
#  29763,
#  516,
#  11881,
#  11,
#  3417,
#  1973,
#  13817,
#  355,
#  257,
#  16396,
#  31184,
#  341,
#  7346,
#  262,
#  1692,
#  1767,
#  11,
#  9179,
#  355,
#  257,
#  7696,
#  1022,
#  262,
#  3518,
#  290,
#  42031,
#  35423,
#  11,
#  6011,
#  17218,
#  656,
#  281,
#  1981,
#  338,
#  7016,
#  11,
#  5110,
#  11,
#  290,
#  8557,
#  2585,
#  13,
#  383,
#  2050,
#  286,
#  257,
#  17786,
#  10069,
#  257,
#  5527,
#  9814,
#  395,
#  563,
#  286,
#  3272,
#  12,
#  30844,
#  8557,
#  11501,
#  11,
#  422,
#  6156,
#  16397,
#  39782,
#  284,
#  3660,
#  968,
#  7129,
#  6593,
#  11,
#  21135,
#  9265,
#  338,
#  16218,
#  35556,
#  351,
#  262,
#  14836,
#  3386,
#  326,
#  5485,
#  674,
#  6224,
#  290,
#  10510,
#  13,
#  198,
#  198,
#  13749,
#  12409,
#  290,
#  23897,
#  4062,
#  602,
#  198,
#  44974,
#  24079,
#  290,
#  6372,
#  12,
#  34,
#  8596,
#  36757,
#  602,
#  198,
#  464,
#  4901,
#  287,
#  257,
#  17786,
#  14582,
#  1290,
#  736,
#  656,
#  1692,
#  2106,
#  11,
#  351,
#  12395,
#  2370,
#  12655,
#  287,
#  2972,
#  6156,
#  35928,
#  290,
#  8557,
#  15421,
#  13,
#  554,
#  6156,
#  3794,
#  11,
#  262,
#  3721,
#  7228,
#  663,
#  14555,
#  6264,
#  15802,
#  287,
#  262,
#  16397,
#  39782,
#  1900,
#  355,
#  262,
#  3205,
#  7115,
#  5643,
#  11,
#  3194,
#  1022,
#  10460,
#  290,
#  7337,
#  37078,
#  11,
#  543,
#  6901,
#  262,
#  3721,
#  286,
#  778,
#  2271,
#  11,
#  393,
#  1204,
#  2700,
#  2568,
#  13,
#  2312,
#  13626,
#  13399,
#  4545,
#  326,
#  778,
#  2271,
#  15623,
#  832,
#  477,
#  2877,
#  9791,
#  290,
#  460,
#  307,
#  11067,
#  832,
#  16901,
#  290,
#  8557,
#  6593,
#  11,
#  10561,
#  278,
#  355,
#  281,
#  22491,
#  326,
#  12497,
#  281,
#  1981,
#  338,
#  8557,
#  2478,
#  290,
#  9204,
#  12799,
#  13,
#  383,
#  3205,
#  7115,
#  5643,
#  4474,
#  262,
#  43936,
#  4547,
#  326,
#  428,
#  2568,
#  2214,
#  9179,
#  355,
#  257,
#  7424,
#  10552,
#  286,
#  530,
#  338,
#  8434,
#  8557,
#  1181,
#  11,
#  4955,
#  257,
#  1724,
#  329,
#  6190,
#  24068,
#  284,
#  4659,
#  290,
#  5698,
#  1854,
#  319,
#  511,
#  8557,
#  7002,
#  13,
#  198,
#  198,
#  44974,
#  3999,
#  6761,
#  8639,
#  5566,
#  284,
#  262,
#  4547,
#  286,
#  2568,
#  7032,
#  832,
#  262,
#  3721,
#  286,
#  10662,
#  72,
#  357,
#  273,
#  33166,
#  828,
#  3616,
#  9204,
#  2568,
#  11,
#  543,
#  2627,
#  4318,
#  284,
#  4569,
#  9007,
#  290,
#  15618,
#  10848,
#  13,
#  3999,
#  9007,
#  24068,
#  290,
#  15618,
#  7912,
#  4499,
#  284,
#  19973,
#  290,
#  18510,
#  428,
#  1204,
#  2700,
#  326,
#  15623,
#  832,
#  4017,
#  312,
#  1547,
#  287,
#  262,
#  1767,
#  11,
#  1262,
#  340,
#  329,
#  11516,
#  290,
#  13105,
#  3518,
#  9889,
#  13,
#  770,
#  17895,
#  3164,
#  284,
#  2568,
#  670,
#  4920,
#  867,
#  286,
#  262,
#  7811,
#  326,
#  561,
#  1568,
#  4588,
#  3660,
#  22491,
#  11516,
#  6593,
#  13,
#  15298,
#  11,
#  6156,
#  14075,
#  14355,
#  2714,
#  9056,
#  546,
#  262,
#  366,
#  4914,
#  553,
#  10200,
#  257,
#  1048,
#  338,
#  8557,
#  12799,
#  326,
#  3767,
#  284,
#  2152,
#  706,
#  1918,
#  11,
#  981,
#  6156,
#  25059,
#  8018,
#  262,
#  366,
#  64,
#  495,
#  2305,
#  553,
#  257,
#  43888,
#  1657,
#  7346,
#  11871,
#  5538,
#  588,
#  11858,
#  290,
#  10281,
#  13,
#  198,
#  198,
#  464,
#  418,
#  49256,
#  35948,
#  290,
#  12495,
#  7712,
#  198,
#  464,
#  3660,
#  4885,
#  4547,
#  286,
#  257,
#  17786,
#  373,
#  5566,
#  14292,
#  416,
#  262,
#  670,
#  286,
#  7516,
#  31890,
#  20116,
#  1350,
#  729,
#  11,
#  257,
#  1966,
#  4564,
#  286,
#  4492,
#  11503,
#  290,
#  2888,
#  286,
#  262,
#  383,
#  418,
#  49256,
#  7023,
#  287,
#  262,
#  1903,
#  1160,
#  400,
#  4289,
#  13,
#  20116,
#  1350,
#  729,
#  4752,
#  284,
#  8588,
#  537,
#  958,
#  40024,
#  415,
#  7883,
#  326,
#  3142,
#  683,
#  284,
#  787,
#  5654,
#  10986,
#  286,
#  262,
#  1692,
#  2568,
#  2214,
#  11,
#  290,
#  465,
#  41625,
#  1492,
#  366,
#  5124,
#  6911,
#  856,
#  290,
#  39571,
#  1,
#  18542,
#  262,
#  22491,
#  379,
#  2972,
#  9539,
#  286,
#  1692,
#  6573,
#  6954,
#  13,
#  2399,
#  12253,
#  10156,
#  1625,
#  287,
#  31953,
#  351,
#  366,
#  464,
#  24877,
#  5155,
#  553,
#  810,
#  339,
#  16560,
#  262,
#  44116,
#  1173,
#  9495,
#  286,
#  442,
#  461,
#  8847,
#  11,
#  12059,
#  606,
#  355,
#  2568,
#  410,
#  419,
#  1063,
#  290,
#  2570,
#  803,
#  1123,
#  351,
#  2176,
#  42093,
#  290,
#  16613,
#  13,
#  770,
#  21263,
#  286,
#  8345,
#  290,
#  4885,
#  44894,
#  15421,
#  2727,
#  262,
#  8489,
#  329,
#  11811,
#  22491,
#  4583,
#  13,
#  198,
#  198,
#  20451,
#  1350,
#  729,
#  338,
#  25438,
#  547,
#  12412,
#  8197,
#  290,
#  302,
#  27381,
#  276,
#  416,
#  584,
#  14212,
#  262,
#  418,
#  2522,
#  1023,
#  884,
#  355,
#  17421,
#  4024,
#  2441,
#  7274,
#  290,
#  29166,
#  28335,
#  344,
#  11,
#  996,
#  262,
#  3721,
#  6150,
#  5365,
#  18611,
#  1566,
#  262,
#  7169,
#  82,
#  618,
#  340,
#  373,
#  18079,
#  416,
#  262,
#  968,
#  7129,
#  3356,
#  13,
#  770,
#  27556,
#  286,
#  1393,
#  2957,
#  284,
#  257,
#  25068,
#  286,
#  22491,
#  12,
#  5363,
#  6593,
#  11,
#  422,
#  22491,
#  16223,
#  284,
#  2568,
#  11516,
#  953,
#  27969,
#  11,
#  15010,
#  257,
#  17786,
#  355,
#  257,
#  4318,
#  7515,
#  286,
#  5559,
#  39409,
#  13,
#  383,
#  262,
#  418,
#  49256,
#  10794,
#  20047,
#  262,
#  5021,
#  12,
#  10724,
#  1068,
#  3450,
#  286,
#  262,
#  22491,
#  11,
#  351,
#  1180,
#  2974,
#  11188,
#  284,
#  2972,
#  7612,
#  286,
#  1692,
#  10510,
#  290,
#  8557,
#  2478,
#  13,
#  198,
#  198,
#  41910,
#  723,
#  290,
#  23945,
#  29845,
#  1083,
#  198,
#  46109,
#  33944,
#  8397,
#  1756,
#  198,
#  33,
#  4185,
#  71,
#  1042,
#  10969,
#  257,
#  13767,
#  4547,
#  286,
#  257,
#  17786,
#  832,
#  262,
#  3721,
#  286,
#  43888,
#  2568,
#  7346,
#  34964,
#  9791,
#  11,
#  6194,
#  2890,
#  511,
#  25590,
#  290,
#  8557,
#  3349,
#  13,
#  383,
#  6761,
#  31648,
#  262,
#  4637,
#  1022,
#  8434,
#  27494,
#  290,
#  23537,
#  2568,
#  30566,
#  11,
#  11681,
#  262,
#  22491,
#  355,
#  257,
#  14580,
#  286,
#  530,
#  338,
#  8557,
#  7002,
#  290,
#  22425,
#  17004,
#  13,
#  383,
#  20838,
#  3721,
#  286,
#  1736,
#  397,
#  17831,
#  85,
#  3301,
#  11,
#  5734,
#  3519,
#  284,
#  402,
#  2306,
#  1689,
#  19154,
#  338,
#  22491,
#  11,
#  10874,
#  286,
#  1936,
#  7310,
#  7577,
#  25,
#  473,
#  381,
#  10695,
#  4171,
#  357,
#  77,
#  18962,
#  5031,
#  828,
#  10861,
#  7872,
#  357,
#  79,
#  18962,
#  8326,
#  828,
#  46153,
#  357,
#  75,
#  1219,
#  270,
#  8130,
#  828,
#  2330,
#  357,
#  375,
#  10235,
#  8326,
#  828,
#  290,
#  10912,
#  393,
#  10153,
#  1616,
#  357,
#  2611,
#  12654,
#  18015,
#  26292,
#  255,
#  26292,
#  255,
#  3099,
#  737,
#  770,
#  5021,
#  12,
#  25717,
#  2511,
#  3610,
#  6870,
#  262,
#  19154,
#  338,
#  2818,
#  35957,
#  290,
#  9179,
#  355,
#  257,
#  6194,
#  286,
#  262,
#  8713,
#  8557,
#  13293,
#  1744,
#  329,
#  1692,
#  10510,
#  13,
#  198,
#  198,
#  39,
#  10259,
#  6761,
#  3769,
#  3737,
#  262,
#  749,
#  9815,
#  9355,
#  329,
#  4547,
#  257,
#  17786,
#  11,
#  12059,
#  606,
#  355,
#  304,
#  37827,
#  14482,
#  7346,
#  262,
#  1767,
#  326,
#  4079,
#  663,
#  3124,
#  290,
#  2511,
#  3610,
#  13,
#  383,
#  36101,
#  291,
#  6761,
#  30742,
#  262,
#  22491,
#  355,
#  281,
#  19287,
#  7515,
#  286,
#  1692,
#  26758,
#  33449,
#  11,
#  17747,
#  286,
#  3598,
#  7310,
#  11685,
#  326,
#  6053,
#  284,
#  2972,
#  7612,
#  286,
#  3518,
#  11,
#  5110,
#  11,
#  7016,
#  11,
#  290,
#  8557,
#  1535,
#  13,
#  5501,
#  7679,
#  318,
#  40582,
#  351,
#  262,
#  1854,
#  11,
#  4441,
#  257,
#  8925,
#  1080,
#  810,
#  545,
#  6893,
#  1817,
#  287,
#  530,
#  1989,
#  460,
#  2689,
#  4045,
#  880,
#  12,
#  11873,
#  290,
#  2568,
#  5202,
#  13,
#  770,
#  42923,
#  3164,
#  21570,
#  262,
#  22491,
#  355,
#  1111,
#  257,
#  23584,
#  2891,
#  290,
#  257,
#  21182,
#  329,
#  11516,
#  ...]

# %%
enc_sample = enc_text[50:]

# %%
context_size = 4
x = enc_sample[:context_size]
y = enc_sample[1:context_size+1]
print(f"x:{x}")
print(f"y :   {y}")
# Out:
# x:[307, 11067, 11, 16173]
# y :   [11067, 11, 16173, 11]

# %%
 for i in range(1,context_size+1):
     context = enc_sample[:i]
     desired = enc_sample[i]
     print(context,"---->",desired)
# Out:
# [307] ----> 11067
# [307, 11067] ----> 11
# [307, 11067, 11] ----> 16173
# [307, 11067, 11, 16173] ----> 11

# %%
for i in range(1,context_size+1):
     context = enc_sample[:i]
     desired = enc_sample[i]
     print(tik_tokenizer.decode(context),"---->",tik_tokenizer.decode([desired]))
# Out:
#  be ---->  perceived
#  be perceived ----> ,
#  be perceived, ---->  interpreted
#  be perceived, interpreted ----> ,

# %%
import torch 
from torch.utils.data import Dataset,DataLoader 

class GPTDatasetV1(Dataset):
    def __init__(self,txt,tokenizer,max_length,stride):
        self.input_ids = []
        self.target_ids = []
        
        token_ids = tokenizer.encode(txt)
        
        for i in range(0,len(token_ids) - max_length,stride):
            input_chunk = token_ids[i:i+max_length]
            target_chunk = token_ids[i+1:i+max_length + 1]
            self.input_ids.append([torch.tensor(input_chunk)])
            self.target_ids.append(torch.tensor(target_chunk))
            
    def __len__(self):
            return len(self.input_ids)
        
    def __getitem__(self,idx):
            return self.input_ids[idx],self.target_ids[idx]
        
def create_dataloader_v1(txt,batch_size = 4, max_length =256,stride=128,shuffle=True,drop_last=True,num_workers=0):
    tokenizer = tiktoken.get_encoding("gpt2")
    dataset = GPTDatasetV1(txt,tokenizer,max_length,stride)
    dataloader = DataLoader(dataset,batch_size=batch_size,shuffle=shuffle,drop_last=drop_last,num_workers=num_workers)
    
    return dataloader


dataloader = create_dataloader_v1(
    raw_text,batch_size=1,max_length=4,stride=1,shuffle=False
)
data_iter = iter(dataloader)
first_batch = next(data_iter)
print(first_batch)
# Out:
# [[tensor([[  464, 33944, 34828,  3674]])], tensor([[33944, 34828,  3674,   261]])]

# %%
second_batch = next(data_iter)
print(second_batch)
# Out:
# [[tensor([[33944, 34828,  3674,   261]])], tensor([[34828,  3674,   261,   286]])]

# %% [markdown]
# ## Creating token embeddings

# %%
input_ids = torch.tensor([2,3,5,1])

# %%
vocab_size = 6
output_dim = 3 


torch.manual_seed(123)
embedding_layer = torch.nn.Embedding(vocab_size,output_dim)
print(embedding_layer.weight)
# Out:
# Parameter containing:
# tensor([[ 0.3374, -0.1778, -0.1690],
#         [ 0.9178,  1.5810,  1.3010],
#         [ 1.2753, -0.2010, -0.1606],
#         [-0.4015,  0.9666, -1.1481],
#         [-1.1589,  0.3255, -0.6315],
#         [-2.8400, -0.7849, -1.4096]], requires_grad=True)

# %%
print(embedding_layer(torch.tensor([3])))
# Out:
# tensor([[-0.4015,  0.9666, -1.1481]], grad_fn=<EmbeddingBackward0>)

# %%
print(embedding_layer(torch.tensor(input_ids)))
# Out:
# tensor([[ 1.2753, -0.2010, -0.1606],
#         [-0.4015,  0.9666, -1.1481],
#         [-2.8400, -0.7849, -1.4096],
#         [ 0.9178,  1.5810,  1.3010]], grad_fn=<EmbeddingBackward0>)
# C:\Users\HP\AppData\Local\Temp\ipykernel_13176\3846183200.py:1: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   print(embedding_layer(torch.tensor(input_ids)))

# %%
 #Encoding Word positions 
 #An embedding vector is a dense numerical representation of a categorical input (like a word or token), where similar tokens get similar vectors.

# %% [markdown]
# ## Encoding Word Positions

# %%
vocab_size = 50257
output_dim = 256 

token_embedding_layer = torch.nn.Embedding(vocab_size,output_dim)

print(token_embedding_layer.weight)
# Out:
# Parameter containing:
# tensor([[ 0.7504,  0.7353,  1.7375,  ..., -0.2488, -0.7666, -0.2277],
#         [ 0.5131, -0.2599,  1.6423,  ..., -0.0586,  1.3007,  0.4118],
#         [ 0.1582, -1.1788, -0.4651,  ...,  0.8060, -0.0383,  1.4335],
#         ...,
#         [-0.2420,  0.8730, -0.1769,  ...,  1.1450, -0.8330, -0.6994],
#         [ 0.1242,  0.0251, -0.0437,  ..., -0.6893,  0.0598,  0.0348],
#         [ 1.0846, -0.1639, -0.1025,  ..., -1.0124, -1.5893,  0.7799]],
#        requires_grad=True)
